# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul7677/My-First-Project/blob/main/Data_Science_Job_Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/data_science_jobs.csv')
df.head()
# Out:
#                                            Job Title     Company Name  \
# 0                              Intern - Data Science             Yubi
# 1                                Data Science Intern         Mhtechin
# 2  S&C Global Network - AI - CG&S - Viz Analyst D...        Accenture
# 3                               Data Science Analyst      Fortune 500
# 4                              Data Science Engineer  Electronic Arts
#
#                      Location Experience(Yrs)  \
# 0          Chennai, Bengaluru             0-1
# 1                        Pune             0-3
# 2                   Bengaluru           3-Jan
# 3  Hyderabad, Pune, Bengaluru           7-Feb
# 4                   Hyderabad           4-Feb
#
#                                      Job Description  \
# 0  Yubi, formerly known as CredAvenue, is re-defi...
# 1  We are seeking a highly motivated Data Science...
# 2  Educational Qualification: Bachelors or master...
# ...

# %%
df.shape
# Out:
# (15243, 7)

# %%
df.describe()
# Out:
#                Job Title Company Name   Location Experience(Yrs)  \
# count              15239        15239      15239           15239
# unique              8059         5294        954             168
# top     Business Analyst    Accenture  Bengaluru           5-Feb
# freq                1180          639       3779             994
#
#                                           Job Description  \
# count                                               15239
# unique                                              13163
# top     Scope Management. SQL. Stakeholder Management....
# freq                                                   88
#
#                                      Skills  Job Post Day
# count                                 15239         15239
# unique                                13782            33
# top     Business Analyst, Business analysis  30+ Days Ago
# freq                                     64          7468

# %%
df1=pd.read_csv('/content/Book1.csv')
df1.head()
# Out:
#                                            Job Title     Company Name  \
# 0                              Intern - Data Science             Yubi
# 1                                Data Science Intern         Mhtechin
# 2  S&C Global Network - AI - CG&S - Viz Analyst D...        Accenture
# 3                               Data Science Analyst      Fortune 500
# 4                              Data Science Engineer  Electronic Arts
#
#                      Location Experience(Yrs)  \
# 0          Chennai, Bengaluru             0-1
# 1                        Pune             0-3
# 2                   Bengaluru          03-Jan
# 3  Hyderabad, Pune, Bengaluru          07-Feb
# 4                   Hyderabad          04-Feb
#
#                                      Job Description  \
# 0  Yubi, formerly known as CredAvenue, is re-defi...
# 1  We are seeking a highly motivated Data Science...
# 2  Educational Qualification: Bachelors or master...
# ...

# %%
df1.shape
# Out:
# (9663, 7)

# %%
df.isnull().sum()
# Out:
# Job Title          0
# Company Name       3
# Location           0
# Experience(Yrs)    0
# Job Description    0
# Skills             1
# Job Post Day       0
# dtype: int64

# %%
df = df.dropna(subset=['Company Name'])  # Removes only rows where Company Name is missing
df=df.dropna(subset=['Skills'])

# %%
df.isnull().sum()
# Out:
# Job Title          0
# Company Name       0
# Location           0
# Experience(Yrs)    0
# Job Description    0
# Skills             0
# Job Post Day       0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#                                                Job Title  \
# 177                                 Data Science Analyst
# 198                   Sr Consultant: Data Science and AI
# 862                           Data Scientist For Top MNC
# 1039                                        Data Analyst
# 1266                                      Data Scientist
# 1323                               Senior Data Scientist
# 1342                                 Senior Data Analyst
# 1618                                      Data Scientist
# 1698                                   Lead Data Analyst
# 1956                                 Lead Data Scientist
# 2034                               Senior Data Scientist
# 3141         Data Operations & Business Insights Manager
# 3280                               Data Analyst - Mumbai
# 3728                                      Data Scientist
# 3937                      Principal Data Quality Analyst
# ...

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Job Title, Company Name, Location, Experience(Yrs), Job Description, Skills, Job Post Day]
# Index: []

# %%
df[df.duplicated()].count()
# Out:
# Job Title          0
# Company Name       0
# Location           0
# Experience(Yrs)    0
# Job Description    0
# Skills             0
# Job Post Day       0
# dtype: int64

# %%
df= df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                            Job Title     Company Name  \
# 0                              Intern - Data Science             Yubi
# 1                                Data Science Intern         Mhtechin
# 2  S&C Global Network - AI - CG&S - Viz Analyst D...        Accenture
# 3                               Data Science Analyst      Fortune 500
# 4                              Data Science Engineer  Electronic Arts
#
#                      Location Experience(Yrs)  \
# 0          Chennai, Bengaluru             0-1
# 1                        Pune             0-3
# 2                   Bengaluru           3-Jan
# 3  Hyderabad, Pune, Bengaluru           7-Feb
# 4                   Hyderabad           4-Feb
#
#                                      Job Description  \
# 0  Yubi, formerly known as CredAvenue, is re-defi...
# 1  We are seeking a highly motivated Data Science...
# 2  Educational Qualification: Bachelors or master...
# ...

# %%
df.shape
# Out:
# (15190, 7)

# %%
print(df['Job Title'].value_counts().head(10))
# Out:
# Job Title
# Business Analyst           1175
# Data Scientist              524
# Data Analyst                459
# Data Engineer               364
# Senior Data Scientist       135
# Senior Data Engineer        127
# Senior Business Analyst     122
# Senior Analyst              110
# Business Advisor - A        102
# Senior Data Analyst          90
# Name: count, dtype: int64

# %%
import plotly.express as px
z=df['Job Title'].value_counts().head(10)
fig=px.bar(z,x=z.index,y=z.values,color=z.index,text=z.values,labels={'index':'job title','y':'count','text':'count'},template='seaborn',title='<b> Top 10 Popular Roles in Data Sceince')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df['Company Name'].value_counts().head(10))
# Out:
# Company Name
# Accenture                      637
# PwC Service Delivery Center    325
# Leading Client                 269
# Amazon                         256
# Capgemini                      190
# EY                             150
# Diverse Lynx                   133
# Fusion Plus Solutions          127
# JPMorgan Chase Bank            119
# Wipro                           78
# Name: count, dtype: int64

# %%
top_companies = df['Company Name'].value_counts().iloc[:10]
plt.figure(figsize=(8,8))
plt.pie(top_companies, labels=top_companies.index, autopct='%1.1f%%', startangle=140)
plt.title("Top 10 Hiring Companies (Pie Chart)", fontsize=14, pad=30)  # <== pad added
plt.axis('equal')
plt.show()

# %%
print(df['Location'].value_counts().head(10))
# Out:
# Location
# Bengaluru                                                          3774
# Hyderabad                                                          1686
# Mumbai                                                             1283
# Pune                                                               1153
# Gurugram                                                           1008
# Chennai                                                             843
# Kolkata, Mumbai, New Delhi, Hyderabad, Pune, Chennai, Bengaluru     549
# Noida                                                               517
# Ahmedabad                                                           252
# Kolkata                                                             242
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
top_locations = df['Location'].value_counts().iloc[:10].index
sns.countplot(y='Location', data=df[df['Location'].isin(top_locations)],
              hue='Location', palette='Set2', legend=False)

plt.title("Top 10 Job Locations", fontsize=16, pad=15)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
colors = sns.color_palette("Set2", n_colors=10)
top_bangalore_df = top_bangalore_companies.reset_index()
top_bangalore_df.columns = ['Company Name', 'Job Count']

plt.figure(figsize=(12,7))
sns.barplot(data=top_bangalore_df, x='Company Name', y='Job Count', hue='Company Name', palette=colors, legend=False)
plt.title("Top 10 Companies in Bangalore (Job Listings)", fontsize=16, pad=20)
plt.xlabel("Company Name")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45, ha='right')
plt.subplots_adjust(bottom=0.2)
plt.show()

# %%
df['Experience_Years'] = df['Experience(Yrs)'].str.extract(r'(\d+)').astype(float)
df['Experience_Years'] = df['Experience_Years'].astype(int)
print(df[['Experience(Yrs)', 'Experience_Years']])
# Out:
#       Experience(Yrs)  Experience_Years
# 0                 0-1                 0
# 1                 0-3                 0
# 2               3-Jan                 3
# 3               7-Feb                 7
# 4               4-Feb                 4
# ...               ...               ...
# 15185          11-Jun                11
# 15186           9-Aug                 9
# 15187           8-Jun                 8
# 15188           9-Aug                 9
# 15189          15-Oct                15
#
# [15190 rows x 2 columns]

# %%
print(df['Experience_Years'].value_counts().sort_index())
# Out:
# Experience_Years
# 0      829
# 2      189
# 3      796
# 4     1138
# 5     2094
# 6     1756
# 7     1630
# 8     1909
# 9      943
# 10    1515
# 11     424
# 12     666
# 13     545
# 14     167
# 15     348
# 16      61
# 17      38
# 18      36
# 19      10
# 20      85
# 21       5
# 22       4
# 25       2
# Name: count, dtype: int64

# %%
top_10 = df['Experience_Years'].value_counts().nlargest(10)
top_10_sorted = top_10.sort_index()
print(top_10_sorted)
# Out:
# Experience_Years
# 0      829
# 3      796
# 4     1138
# 5     2094
# 6     1756
# 7     1630
# 8     1909
# 9      943
# 10    1515
# 12     666
# Name: count, dtype: int64

# %%
import plotly.express as px
import pandas as pd
exp_df = top_10_sorted.reset_index()
exp_df.columns = ['Experience_Years', 'Job_Count']
fig = px.pie(
    exp_df,
    names='Experience_Years',
    values='Job_Count',
    color='Experience_Years',
    hole=0.6,
    labels={'Experience_Years': 'Experience (Years)', 'Job_Count': 'Number of Jobs'},
    template='ggplot2',
    title='<b>Top 5 Most Frequent Experience Levels'
)
fig.update_layout(
    title_x=0.5,
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=1.02,
        xanchor='right',
        x=1
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd

# Sample column name (adjust if yours is different)
# Example: 'Job_Posted' column contains "3 days ago", "30+ days ago", etc.
# Make sure you load your dataset first if not already done.

# Step 1: Clean and extract numeric values from text
df['Days_Ago'] = df['Job Post Day'].str.extract(r'(\d+)').astype(float)

# Step 2: Handle 30+ as a special case (replace 30+ with a number, e.g., 31 or keep it as 30)
# Optional: Fill NaN (in case anything is missing)
df['Days_Ago'] = df['Days_Ago'].fillna(0)

# Step 3: Filter rows posted within last 30 days
jobs_within_30_days = df[df['Days_Ago'] < 30]
jobs_with_30_days =df[df['Days_Ago']>=30]

# Display result
print(jobs_within_30_days[['Job Post Day', 'Days_Ago']])
Juniors = len(jobs_within_30_days)
print("Total jobs posted within last 30 days:", len(jobs_within_30_days))
print("Total jobs posted more than  last 30 days:", len(jobs_with_30_days))
# Out:
#       Job Post Day  Days_Ago
# 0        1 Day Ago       1.0
# 1        1 Day Ago       1.0
# 2        1 Day Ago       1.0
# 3       8 Days Ago       8.0
# 4        1 Day Ago       1.0
# ...            ...       ...
# 15030  22 Days Ago      22.0
# 15049  23 Days Ago      23.0
# 15073  28 Days Ago      28.0
# 15090  29 Days Ago      29.0
# 15097  29 Days Ago      29.0
#
# [7441 rows x 2 columns]
# Total jobs posted within last 30 days: 7441
# Total jobs posted more than  last 30 days: 7749

# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
labels = ['Within 30 Days', 'More than 30 Days']
sizes = [7441, 7749]
colors = ['skyblue', 'salmon']
fig, ax = plt.subplots(figsize=(8,8))
wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    wedgeprops=dict(width=0.4),
    textprops={'fontsize': 12}
)

plt.title("Job Posts: Within vs More than 30 Days", fontsize=15, pad=20)
plt.tight_layout()
plt.show()

# %%
data1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder_X = LabelEncoder()
for i in data1.columns:
    data1[i] = labelencoder_X.fit_transform(data1[i])

# %%
data1.head()
# Out:
#    Job Title  Company Name  Location  Experience(Yrs)  Job Description  \
# 0       4058          5152       118                1            12917
# 1       2787          2989       813                5            12404
# 2       5841           145        47              133             4647
# 3       2767          1805       436              148             4050
# 4       2778          1519       395              134             7435
#
#    Skills  Job Post Day  Experience_Years  Days_Ago
# 0    9207             0                 0         1
# 1    5495             0                 0         1
# 2   13045             0                 2         1
# 3    4412            29                 6         8
# 4   12255             0                 3         1

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset

X = data1.iloc[:, [0,1]].values

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
